# %% [markdown]
# # 2D Gauss dataset clustering
#
# ## 2.1 K-means design and implementation

# %%
# load the dataset using numpy.loadtxt
import numpy as np

# %%
with open('./2D_gauss_clusters.txt', 'rb') as f:
    ds_arr = np.loadtxt(f,dtype=np.uint32, skiprows=1, delimiter=',')
    
ds_arr
# Out:
# array([[845753, 636607],
#        [812954, 643720],
#        [868217, 609046],
#        ...,
#        [706472, 171207],
#        [659128, 142611],
#        [665898,  98088]], dtype=uint32)

# %%
# plot the points as a scatter chart with matplotlib
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
ax.scatter(ds_arr[:,0], ds_arr[:,1])
plt.show()

# %% [markdown]
# _Answer the question point 2.1.2_

# %%
from my_kmeans import KMeans
kmeans = KMeans(15, 0)
KMeans.fit_predict(ds_arr)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-7bece317dd9b> in <module>
#       1 from my_kmeans import KMeans
#       2 kmeans = KMeans(15, 0)
# ----> 3 KMeans.fit_predict(ds_arr)
#
# TypeError: fit_predict() missing 1 required positional argument: 'X'
